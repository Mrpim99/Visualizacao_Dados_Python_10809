# %% [markdown]
# # 📘 Ficha de Exercícios - Visualização com Matplotlib
#
# ## 🗂️ Contextualização do Dataset: Iris
#
# O dataset **Iris** é um dos conjuntos de dados mais conhecidos em estatística e ciência de dados. Foi publicado pelo estatístico britânico **Ronald A. Fisher** em 1936, e contém informações sobre 150 amostras de flores da espécie *Iris*, divididas em três subespécies:
#
# - *Iris setosa*
# - *Iris versicolor*
# - *Iris virginica*
#
# Para cada flor, foram recolhidas quatro medidas:
#
# - **Comprimento da sépala** (*sepal_length*)
# - **Largura da sépala** (*sepal_width*)
# - **Comprimento da pétala** (*petal_length*)
# - **Largura da pétala** (*petal_width*)
#
# Estas medidas estão expressas em centímetros (cm) e permitem distinguir facilmente entre as espécies com recurso a visualizações.
#
# Este dataset é ideal para aprender a utilizar bibliotecas de visualização como o **Matplotlib**, explorando relações entre variáveis, distribuições e comparações entre grupos.

# %%
# 📦 Importação de bibliotecas
import pandas as pd
import matplotlib.pyplot as plt

# 📥 Carregamento do dataset
url = "https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv"
df = pd.read_csv(url)

# 👀 Visualização inicial dos dados
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## 📊 Exemplo 1: Gráfico de Dispersão
#
# Visualização da relação entre duas variáveis numéricas com um gráfico de dispersão (scatter plot).

# %%
# Relação entre comprimento e largura da pétala
plt.figure(figsize=(6, 4))
plt.scatter(df['petal_length'], df['petal_width'], color='blue')
plt.title("Comprimento vs Largura da Pétala")
plt.xlabel("Comprimento da Pétala (cm)")
plt.ylabel("Largura da Pétala (cm)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### 📝 Exercício 1:
# Cria um gráfico de dispersão para analisar a relação entre o **comprimento e a largura da sépala**.
# Inclui os rótulos dos eixos e o título do gráfico.

# %%
plt.figure(figsize=(6, 4))
plt.scatter(df['sepal_length'], df['sepal_width'], color='blue')
plt.title("Comprimento vs Largura da Pétala")
plt.xlabel("Comprimento da Pétala (cm)")
plt.ylabel("Largura da Pétala (cm)")
plt.grid(True)
plt.show()

# %%
 #Cores por espécie
cores = {
    'setosa': 'blue',
    'versicolor': 'green',
    'virginica': 'red'
}

plt.figure(figsize=(6, 4))

# Plotar cada espécie separadamente
for especie in df['species'].unique():
    subset = df[df['species'] == especie]
    plt.scatter(subset['sepal_length'], subset['sepal_width'],
                color=cores[especie], label=especie, edgecolors='black', s=40)

plt.title("Comprimento vs Largura da Sépala por Espécie")
plt.xlabel("Comprimento da Sépala (cm)")
plt.ylabel("Largura da Sépala (cm)")
plt.grid(True)
plt.legend(title="Espécie")
plt.show()

# %% [markdown]
# #### ✅ Resolução do Exercício 1:
# Vamos criar um gráfico de dispersão entre o comprimento e a largura da sépala.
# 1. Utilizamos `plt.scatter()` para gerar o gráfico.
# 2. Usamos os campos `sepal_length` e `sepal_width` como variáveis.
# 3. Adicionamos rótulos e título para legibilidade.

# %%
plt.figure(figsize=(6, 4))
plt.scatter(df['sepal_length'], df['sepal_width'], color='teal')
plt.title("Comprimento vs Largura da Sépala")
plt.xlabel("Comprimento da Sépala (cm)")
plt.ylabel("Largura da Sépala (cm)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 📈 Exemplo 2: Gráfico de Linhas
#
# Visualização de valores agregados (como médias) por categoria usando linhas.

# %%
# Média do comprimento da pétala por espécie
medias = df.groupby("species")["petal_length"].mean()

plt.figure(figsize=(6, 4))
plt.plot(medias.index, medias.values, marker='o', linestyle='-', color='green')
plt.title("Média do Comprimento da Pétala por Espécie")
plt.xlabel("Espécie")
plt.ylabel("Comprimento Médio da Pétala (cm)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### 📝 Exercício 2:
# Cria um gráfico de linhas que represente a **média da largura da sépala** por espécie.
# Inclui marcadores nos pontos e personaliza o gráfico.

# %% [markdown]
# #### ✅ Resolução do Exercício 2:
# 1. Agrupamos o dataset pela coluna `species`.
# 2. Calculamos a média de `sepal_width`.
# 3. Usamos `plt.plot()` com marcadores para representar as médias.

# %%
media_sepala = df.groupby("species")["sepal_width"].mean()
plt.figure(figsize=(6, 4))
plt.plot(media_sepala.index, media_sepala.values, marker='s', linestyle='--', color='darkorange')
plt.title("Média da Largura da Sépala por Espécie")
plt.xlabel("Espécie")
plt.ylabel("Largura Média da Sépala (cm)")
plt.grid(True)
plt.show()

# %% [markdown]
# 🔍 O que foi adicionado:
# plt.text(...) escreve acima de cada ponto:
#
# Nome da espécie (especie)
#
# Valor médio com 2 casas decimais ({valor:.2f})
#
# O \n quebra a linha entre nome e valor
#
# tight_layout() ajuda a evitar cortes nos rótulos

# %%
media_sepala = df.groupby("species")["sepal_width"].mean()

plt.figure(figsize=(6, 4))
plt.plot(media_sepala.index, media_sepala.values, marker='s', linestyle='--', color='darkorange')

# Adicionar texto sobre cada ponto
for i, especie in enumerate(media_sepala.index):
    valor = media_sepala.values[i]
    plt.text(i, valor + 0.05, f"{especie}\n{valor:.2f}", ha='center', va='bottom')

plt.title("Média da Largura da Sépala por Espécie")
plt.xlabel("Espécie")
plt.ylabel("Largura Média da Sépala (cm)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📊 Exemplo 3: Gráfico de Barras
#
# Visualização de quantidades ou valores agregados por categoria com barras verticais.

# %%
# Número de registos por espécie
contagem = df["species"].value_counts()

plt.figure(figsize=(6, 4))
plt.bar(contagem.index, contagem.values, color='purple')
plt.title("Número de Amostras por Espécie")
plt.xlabel("Espécie")
plt.ylabel("Número de Amostras")
plt.show()

# %% [markdown]
# ### 📝 Exercício 3:
# Cria um gráfico de barras com a **média do comprimento da sépala** por espécie.
# Adiciona título e rótulos nos eixos.

# %% [markdown]
# #### ✅ Resolução do Exercício 3:
# 1. Agrupamos os dados por espécie.
# 2. Calculamos a média de `sepal_length`.
# 3. Representamos com `plt.bar()`.

# %%
media_sepal_length = df.groupby("species")["sepal_length"].mean()
plt.figure(figsize=(6, 4))
plt.bar(media_sepal_length.index, media_sepal_length.values, color='skyblue')
plt.title("Comprimento Médio da Sépala por Espécie")
plt.xlabel("Espécie")
plt.ylabel("Comprimento Médio da Sépala (cm)")
plt.show()

# %% [markdown]
# 🧠 O que acontece aqui:
# bar.get_height() devolve o valor da barra
#
# plt.text(...) posiciona o texto centrado no topo
#
# + 1 dá um pequeno espaço acima da barra para o texto não ficar colado

# %%
media_sepal_length = df.groupby("species")["sepal_length"].mean()

plt.figure(figsize=(6, 4))
bars = plt.bar(media_sepal_length.index, media_sepal_length.values, color='skyblue')

# Adicionar valores em cima de cada barra
for bar in bars:
    altura = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, altura + 0.05,
             f"{altura:.2f}", ha='center', va='bottom', fontsize=10)

plt.title("Comprimento Médio da Sépala por Espécie")
plt.xlabel("Espécie")
plt.ylabel("Comprimento Médio da Sépala (cm)")
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# Aqui está a versão com os valores mostrados dentro das barras (em vez de por cima), e ainda com cores diferentes para cada espécie no texto, usando apenas matplotlib
#
# Também:
# 🔍 Notas:
# f"{altura:.2f}": mostra o valor com 2 casas decimais
#
# + 0.05: espaço acima da barra
#
# ha='center': centraliza o texto

# %%
media_sepal_length = df.groupby("species")["sepal_length"].mean()

# Cores por espécie (usadas tanto na barra como no texto)
cores = {
    'setosa': 'steelblue',
    'versicolor': 'mediumseagreen',
    'virginica': 'tomato'
}

plt.figure(figsize=(6, 4))
bars = plt.bar(media_sepal_length.index, media_sepal_length.values,
               color=[cores[especie] for especie in media_sepal_length.index])

# Adicionar valores DENTRO das barras com a cor correspondente
for bar in bars:
    altura = bar.get_height()
    especie = bar.get_x() + bar.get_width()/2
    plt.text(especie, altura - 0.2,  # posiciona mais abaixo
             f"{altura:.2f}", 
             ha='center', va='top', 
             fontsize=10, color='white', fontweight='bold')

plt.title("Comprimento Médio da Sépala por Espécie")
plt.xlabel("Espécie")
plt.ylabel("Comprimento Médio da Sépala (cm)")
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📊 Exemplo 4: Histograma
#
# Visualização da distribuição de uma variável contínua.

# %%
# Distribuição do comprimento da pétala
plt.figure(figsize=(6, 4))
plt.hist(df["petal_length"], bins=15, color='orange', edgecolor='black')
plt.title("Distribuição do Comprimento da Pétala")
plt.xlabel("Comprimento da Pétala (cm)")
plt.ylabel("Frequência")
plt.show()

# %% [markdown]
# ### 📝 Exercício 4:
# Cria um histograma para representar a **distribuição da largura da sépala**.
# Usa pelo menos 10 intervalos (bins).

# %% [markdown]
# #### ✅ Resolução do Exercício 4:
# 1. Selecionamos a coluna `sepal_width`.
# 2. Criamos um histograma com `plt.hist()`.
# 3. Definimos `bins=10` conforme solicitado.

# %%
plt.figure(figsize=(6, 4))
plt.hist(df["sepal_width"], bins=10, color='salmon', edgecolor='black')
plt.title("Distribuição da Largura da Sépala")
plt.xlabel("Largura da Sépala (cm)")
plt.ylabel("Frequência")
plt.show()

# %% [markdown]
# 🔍 Explicação:
# plt.hist(...) retorna:
#
# contagens: nº de ocorrências por bin
#
# bins: limites de cada intervalo
#
# patches: as barras desenhadas
#
# plt.text(...): escreve o número no centro de cada barra

# %%
plt.figure(figsize=(6, 4))

# Criar histograma e capturar as barras
contagens, bins, patches = plt.hist(df["sepal_width"], bins=10, color='salmon', edgecolor='black')

# Adicionar valores em cima de cada barra
for i in range(len(patches)):
    altura = patches[i].get_height()
    if altura > 0:
        plt.text(patches[i].get_x() + patches[i].get_width()/2, altura + 0.5,
                 str(int(altura)), ha='center', va='bottom', fontsize=10)

plt.title("Distribuição da Largura da Sépala")
plt.xlabel("Largura da Sépala (cm)")
plt.ylabel("Frequência")
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📊 Exemplo 5: Gráfico de Setores (Pizza)
#
# Visualização da proporção de categorias numa variável qualitativa.

# %%
# Proporção de espécies no dataset
contagem = df["species"].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(contagem.values, labels=contagem.index, autopct='%1.1f%%', startangle=140)
plt.title("Distribuição de Espécies no Dataset")
plt.show()

# %% [markdown]
# ### 📝 Exercício 5:
# Cria um gráfico de setores com a **frequência das espécies** no dataset.
# Inclui percentagens e título.

# %% [markdown]
# #### ✅ Resolução do Exercício 5:
# 1. Contamos o número de amostras por espécie com `value_counts()`.
# 2. Criamos um gráfico de setores com `plt.pie()` e adicionamos percentagens.

# %%
contagem = df["species"].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(contagem.values, labels=contagem.index, autopct='%1.1f%%', startangle=90)
plt.title("Proporção de Espécies no Conjunto de Dados")
plt.show()

# %% [markdown]
# Versão Melhorada:
# Explicações das melhorias:
# colors=...: define cores diferentes para cada fatia
#
# wedgeprops={'edgecolor': 'black'}: contorno preto para melhor definição
#
# tight_layout(): evita cortes

# %%
contagem = df["species"].value_counts()

# Definir cores personalizadas
cores = ['skyblue', 'lightgreen', 'lightcoral']

plt.figure(figsize=(6, 6))
plt.pie(contagem.values,
        labels=contagem.index,
        autopct='%1.1f%%',
        startangle=90,
        colors=cores,
        wedgeprops={'edgecolor': 'black'})

plt.title("Proporção de Espécies no Conjunto de Dados")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🧠 Desafio Final
#
# ### 🏁 Desafio:
# Cria um gráfico que combine múltiplos tipos (por exemplo, barras e linhas) para representar **duas variáveis diferentes por espécie** (ex: comprimento e largura da pétala).
# Podes usar `plt.twinx()` ou criar duas figuras lado a lado.

# %% [markdown]
# #### ✅ Resolução do Desafio Final:
# 1. Calculamos duas médias por espécie: `petal_length` e `petal_width`.
# 2. Representamos uma com barras e outra com linha.
# 3. Usamos `twinx()` para criar dois eixos y independentes no mesmo gráfico.

# %%
fig, ax1 = plt.subplots(figsize=(8, 5))

especies = df['species'].unique()
media_petal_length = df.groupby('species')['petal_length'].mean()
media_petal_width = df.groupby('species')['petal_width'].mean()

# Barras para comprimento
ax1.bar(especies, media_petal_length, color='lightblue', label='Comprimento')
ax1.set_xlabel('Espécie')
ax1.set_ylabel('Comprimento Médio da Pétala', color='blue')

# Linha para largura
ax2 = ax1.twinx()
ax2.plot(especies, media_petal_width, color='red', marker='o', label='Largura')
ax2.set_ylabel('Largura Média da Pétala', color='red')

plt.title("Comparação: Comprimento vs Largura da Pétala por Espécie")
plt.grid(True)
plt.show()

# %% [markdown]
# ✅ Resultado:
# A legenda mostra: Comprimento (barras) + Largura (linha)
#
# A legenda aparece no canto superior esquerdo
#
# Tudo continua 100% com matplotlib

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(8, 5))

# Obter médias
media_petal_length = df.groupby('species')['petal_length'].mean()
media_petal_width = df.groupby('species')['petal_width'].mean()

# Cores por espécie
cores = {
    'setosa': 'steelblue',
    'versicolor': 'mediumseagreen',
    'virginica': 'darkorange'
}

# Criar barras com cor e legenda
barras = []
labels = []
for especie in media_petal_length.index:
    bar = ax1.bar(especie, media_petal_length[especie],
                  color=cores[especie])
    barras.append(bar[0])  # bar é um container
    labels.append(f'{especie} (comprimento)')

ax1.set_xlabel('Espécie')
ax1.set_ylabel('Comprimento Médio da Pétala', color='blue')

# Criar linha no eixo secundário
ax2 = ax1.twinx()
linha, = ax2.plot(media_petal_width.index, media_petal_width.values,
                  color='red', marker='o', label='Largura média')
ax2.set_ylabel('Largura Média da Pétala', color='red')

# Adicionar legenda (barras + linha)
handles = barras + [linha]
labels += ['Largura média']
ax1.legend(handles, labels, loc='upper left')

plt.title("Comprimento vs Largura da Pétala por Espécie")
plt.grid(True, axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()
